# %%
PATH2 = "C:/Users/admin/exactpro/prj/th2/pickles/lme/messages_2023-02-13T00-00-00_2023-02-13T23-59-59.pickle"

# %%
from th2_data_services.data import Data
from th2_data_services.data_source import lwdp
from th2_data_services.config import options

# %%
mfr = options.MESSAGE_FIELDS_RESOLVER

# %%
data = Data.from_cache_file(PATH2)

# %%
data.len
# Out:
# 42867

# %%
from th2_data_services.utils.charts.message_rate import message_rate

# %%
message_rate(data)
# Out:
# (<Figure size 1500x550 with 1 Axes>, <Axes: xlabel='Timestamp', ylabel='mps'>)

# %%
message_rate(data.filter(lambda m: mfr.get_type(m) == 'Reject'), aggregation_level='1m')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15752\3145148161.py in <cell line: 1>()
# ----> 1 message_rate(data.filter(lambda m: mfr.get_type(m) == 'Reject'), aggregation_level='1m')
#
# ~\exactpro\prj\th2\internal\DS\github\th2-data-services-utils\th2_data_services\utils\charts\message_rate.py in message_rate(data, categories, aggregation_level, fig_width, fig_height, output_file)
#      84             timestamp_gaps.append([i+1])
#      85             while prev_timestamp != next_timestamp:
# ---> 86                 prev_timestamp += timestamp_gap
#      87                 i += 1
#      88             timestamp_gaps[timestamp_gap_index].append(i+1)
#
# OverflowError: date value out of range

# %%
import matplotlib.pyplot as plt

# %%
plt.ion()

# %%
fig, ax = plt.subplots()

# %%
ln, = ax.plot(range(5))

# %%
ln.set_color('orange')

# %%
plt.ion()

# %%
# pyplot.show()

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.ion()

# %%
mpl.is_interactive()
# Out:
# True

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.plot([1,2,3,4,5,6,7], [10, 50, 100, 23,15,28,45], linewidth = 3, c = 'g')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title("Interactive Plot") #Prints the title on top of graph
plt.xlabel("X-axis")         # Prints X axis label as "X-axis"
plt.ylabel("Y-axis")         # Prints Y axis label as "Y-axis"
# Out:
# Text(0, 0.5, 'Y-axis')
